# %% [markdown]
# # Data Cleaning and Exploration Exercise From Mr Paschal

# %%
#install libraries
import pandas as pd
import numpy as np

# %%
#load the data
df = pd.read_excel('Killa.xlsx')
df.shape
# Out:
# (127, 3)

# %%
df.head()
# Out:
#   First Name    Last Name                                        transaction
# 0    nooeukw  uuoaklowalb  {'tx_id': '5ed3d67b8723c11444c43283', 'tx_date...
# 1    angulbo        seagn  {'tx_id': '5ed3d67b8723c11444c43283', 'tx_date...
# 2     dukowi    eukloomja  {'tx_id': '5ed3d67b8723c11444c43283', 'tx_date...
# 3  ltuoawiob   uuilawobmn  {'tx_id': '5ed3d67b8723c11444c43283', 'tx_date...
# 4    nakuolo       donald  {'tx_id': '5ed3d67b8723c11444c43283', 'tx_date...

# %%
#extract the first and the lastname
df2 = df[['First Name', 'Last Name']]
df2.head()
# Out:
#   First Name    Last Name
# 0    nooeukw  uuoaklowalb
# 1    angulbo        seagn
# 2     dukowi    eukloomja
# 3  ltuoawiob   uuilawobmn
# 4    nakuolo       donald

# %%
#extract the transaction column
df3 = df.drop(['First Name', 'Last Name'], axis='columns')
df3.head()
# Out:
#                                          transaction
# 0  {'tx_id': '5ed3d67b8723c11444c43283', 'tx_date...
# 1  {'tx_id': '5ed3d67b8723c11444c43283', 'tx_date...
# 2  {'tx_id': '5ed3d67b8723c11444c43283', 'tx_date...
# 3  {'tx_id': '5ed3d67b8723c11444c43283', 'tx_date...
# 4  {'tx_id': '5ed3d67b8723c11444c43283', 'tx_date...

# %%
df3.shape
# Out:
# (127, 1)

# %%
df3['transaction'][0]
# Out:
# "{'tx_id': '5ed3d67b8723c11444c43283', 'tx_date': '2020-06-13T05:28:47.543000Z', 'tx_amount': 6192, 'tx_mode': 'Debit', 'tx_channel': 'web', 'bank_name': 'QBank', 'dob': ['1992-11-10 00:00:00']}"

# %%
#get each data from the transaction column and put each in its respective column

df4 = pd.DataFrame()  #cretae an empty dataframe

for i in df3['transaction']:
    dict_format = eval(i)      #eval used to convert to dict
    dict_data = pd.DataFrame(dict_format)
    #print(dict_data)
    df4 = pd.concat([df4, dict_data ])
    #print(df4)

# %%
df4.head()
# Out:
#                       tx_id                      tx_date  tx_amount tx_mode  \
# 0  5ed3d67b8723c11444c43283  2020-06-13T05:28:47.543000Z       6192   Debit
# 0  5ed3d67b8723c11444c43283  2020-06-12T20:22:38.986000Z      38445   Debit
# 0  5ed3d67b8723c11444c43283  2020-06-13T06:00:46.904000Z      29627   Debit
# 0  5ed3d67b8723c11444c43283  2020-06-13T16:10:51.479000Z      27791   Debit
# 0  5ed3d67b8723c11444c43283  2020-06-13T05:28:47.543000Z       6192   Debit
#
#   tx_channel bank_name                  dob
# 0        web     QBank  1992-11-10 00:00:00
# 0     mobile     ABank                  n/a
# 0     mobile     GBank  1992-01-01 00:00:00
# 0        web     KBank  1981-01-07 00:00:00
# 0        web     QBank                  n/a

# %%
df5 = df4.reset_index().drop('index', axis='columns')
df5.head()
# Out:
#                       tx_id                      tx_date  tx_amount tx_mode  \
# 0  5ed3d67b8723c11444c43283  2020-06-13T05:28:47.543000Z       6192   Debit
# 1  5ed3d67b8723c11444c43283  2020-06-12T20:22:38.986000Z      38445   Debit
# 2  5ed3d67b8723c11444c43283  2020-06-13T06:00:46.904000Z      29627   Debit
# 3  5ed3d67b8723c11444c43283  2020-06-13T16:10:51.479000Z      27791   Debit
# 4  5ed3d67b8723c11444c43283  2020-06-13T05:28:47.543000Z       6192   Debit
#
#   tx_channel bank_name                  dob
# 0        web     QBank  1992-11-10 00:00:00
# 1     mobile     ABank                  n/a
# 2     mobile     GBank  1992-01-01 00:00:00
# 3        web     KBank  1981-01-07 00:00:00
# 4        web     QBank                  n/a

# %%
#change n/a values to current datetime

df5.loc[df5['dob'] == 'n/a', 'dob'] = pd.datetime.now()
df5.head()
# Out:
#                       tx_id                      tx_date  tx_amount tx_mode  \
# 0  5ed3d67b8723c11444c43283  2020-06-13T05:28:47.543000Z       6192   Debit
# 1  5ed3d67b8723c11444c43283  2020-06-12T20:22:38.986000Z      38445   Debit
# 2  5ed3d67b8723c11444c43283  2020-06-13T06:00:46.904000Z      29627   Debit
# 3  5ed3d67b8723c11444c43283  2020-06-13T16:10:51.479000Z      27791   Debit
# 4  5ed3d67b8723c11444c43283  2020-06-13T05:28:47.543000Z       6192   Debit
#
#   tx_channel bank_name                         dob
# 0        web     QBank         1992-11-10 00:00:00
# 1     mobile     ABank  2020-10-15 17:07:15.503796
# 2     mobile     GBank         1992-01-01 00:00:00
# 3        web     KBank         1981-01-07 00:00:00
# 4        web     QBank  2020-10-15 17:07:15.503796

# %%
#make a copy of df5
df6 = df5.copy()

# %%
#convert the dob to datatome
df6['dob'] = pd.to_datetime(df6['dob'])
df6.head()
# Out:
#                       tx_id                      tx_date  tx_amount tx_mode  \
# 0  5ed3d67b8723c11444c43283  2020-06-13T05:28:47.543000Z       6192   Debit
# 1  5ed3d67b8723c11444c43283  2020-06-12T20:22:38.986000Z      38445   Debit
# 2  5ed3d67b8723c11444c43283  2020-06-13T06:00:46.904000Z      29627   Debit
# 3  5ed3d67b8723c11444c43283  2020-06-13T16:10:51.479000Z      27791   Debit
# 4  5ed3d67b8723c11444c43283  2020-06-13T05:28:47.543000Z       6192   Debit
#
#   tx_channel bank_name                        dob
# 0        web     QBank 1992-11-10 00:00:00.000000
# 1     mobile     ABank 2020-10-15 17:07:15.503796
# 2     mobile     GBank 1992-01-01 00:00:00.000000
# 3        web     KBank 1981-01-07 00:00:00.000000
# 4        web     QBank 2020-10-15 17:07:15.503796

# %%
#extract the year 
df6['year_of_birth'] = pd.to_datetime(df6['dob']).dt.year
df6.head()
# Out:
#                       tx_id                      tx_date  tx_amount tx_mode  \
# 0  5ed3d67b8723c11444c43283  2020-06-13T05:28:47.543000Z       6192   Debit
# 1  5ed3d67b8723c11444c43283  2020-06-12T20:22:38.986000Z      38445   Debit
# 2  5ed3d67b8723c11444c43283  2020-06-13T06:00:46.904000Z      29627   Debit
# 3  5ed3d67b8723c11444c43283  2020-06-13T16:10:51.479000Z      27791   Debit
# 4  5ed3d67b8723c11444c43283  2020-06-13T05:28:47.543000Z       6192   Debit
#
#   tx_channel bank_name                        dob  year_of_birth
# 0        web     QBank 1992-11-10 00:00:00.000000           1992
# 1     mobile     ABank 2020-10-15 17:07:15.503796           2020
# 2     mobile     GBank 1992-01-01 00:00:00.000000           1992
# 3        web     KBank 1981-01-07 00:00:00.000000           1981
# 4        web     QBank 2020-10-15 17:07:15.503796           2020

# %%
from datetime import date

#get the age
df6['age'] = pd.datetime.now().year - df6['year_of_birth']
df6.head()
# Out:
#                       tx_id                      tx_date  tx_amount tx_mode  \
# 0  5ed3d67b8723c11444c43283  2020-06-13T05:28:47.543000Z       6192   Debit
# 1  5ed3d67b8723c11444c43283  2020-06-12T20:22:38.986000Z      38445   Debit
# 2  5ed3d67b8723c11444c43283  2020-06-13T06:00:46.904000Z      29627   Debit
# 3  5ed3d67b8723c11444c43283  2020-06-13T16:10:51.479000Z      27791   Debit
# 4  5ed3d67b8723c11444c43283  2020-06-13T05:28:47.543000Z       6192   Debit
#
#   tx_channel bank_name                        dob  year_of_birth  age
# 0        web     QBank 1992-11-10 00:00:00.000000           1992   28
# 1     mobile     ABank 2020-10-15 17:07:15.503796           2020    0
# 2     mobile     GBank 1992-01-01 00:00:00.000000           1992   28
# 3        web     KBank 1981-01-07 00:00:00.000000           1981   39
# 4        web     QBank 2020-10-15 17:07:15.503796           2020    0

# %%
#fill the zero age with the mean of the other ages
df6['age'] = df6['age'].apply(lambda x : int(np.mean(df6['age'])) if x == 0 else x)
df6.head()
# Out:
#                       tx_id                      tx_date  tx_amount tx_mode  \
# 0  5ed3d67b8723c11444c43283  2020-06-13T05:28:47.543000Z       6192   Debit
# 1  5ed3d67b8723c11444c43283  2020-06-12T20:22:38.986000Z      38445   Debit
# 2  5ed3d67b8723c11444c43283  2020-06-13T06:00:46.904000Z      29627   Debit
# 3  5ed3d67b8723c11444c43283  2020-06-13T16:10:51.479000Z      27791   Debit
# 4  5ed3d67b8723c11444c43283  2020-06-13T05:28:47.543000Z       6192   Debit
#
#   tx_channel bank_name                        dob  year_of_birth  age
# 0        web     QBank 1992-11-10 00:00:00.000000           1992   28
# 1     mobile     ABank 2020-10-15 17:07:15.503796           2020   11
# 2     mobile     GBank 1992-01-01 00:00:00.000000           1992   28
# 3        web     KBank 1981-01-07 00:00:00.000000           1981   39
# 4        web     QBank 2020-10-15 17:07:15.503796           2020   11

# %%
#drop the dob column

df7 = df6.drop('dob', axis='columns')
df7.head()
# Out:
#                       tx_id                      tx_date  tx_amount tx_mode  \
# 0  5ed3d67b8723c11444c43283  2020-06-13T05:28:47.543000Z       6192   Debit
# 1  5ed3d67b8723c11444c43283  2020-06-12T20:22:38.986000Z      38445   Debit
# 2  5ed3d67b8723c11444c43283  2020-06-13T06:00:46.904000Z      29627   Debit
# 3  5ed3d67b8723c11444c43283  2020-06-13T16:10:51.479000Z      27791   Debit
# 4  5ed3d67b8723c11444c43283  2020-06-13T05:28:47.543000Z       6192   Debit
#
#   tx_channel bank_name  year_of_birth  age
# 0        web     QBank           1992   28
# 1     mobile     ABank           2020   11
# 2     mobile     GBank           1992   28
# 3        web     KBank           1981   39
# 4        web     QBank           2020   11

# %%
#concate with the first name and the last name
df8 = pd.concat([df2, df7], axis='columns')
df8
# Out:
#         First Name             Last Name                     tx_id  \
# 0          nooeukw           uuoaklowalb  5ed3d67b8723c11444c43283
# 1          angulbo                 seagn  5ed3d67b8723c11444c43283
# 2           dukowi             eukloomja  5ed3d67b8723c11444c43283
# 3        ltuoawiob            uuilawobmn  5ed3d67b8723c11444c43283
# 4          nakuolo                donald  5ed3d67b8723c11444c43283
# 5            juagn               ahcnaiz  5ed3d67b8723c11444c43283
# 6        eykeneowj                ijutdh  5ed3d67b8723c11444c43283
# 7            ellbo                sasahn  5ed3d67b8723c11444c43283
# 8          ooadelb                ruktam  5ed3d67b8723c11444c43283
# 9              ali      grgniir kaeouakn  5ed3d67b8723c11444c43283
# 10             ial                ubykua  5ed3d67b8723c11444c43283
# 11       owjoloaur               eaoltse  5ed3d67b8723c11444c43283
# 12       boadigasm         hycknouwyeniu  5ed3d67b8723c11444c43283
# 13          ywmuia  oaeuld omyiosalnfula  5ed3d67b8723c11444c43283
# 14            owug                fuatas  5ed3d67b8723c11444c43283
# 15         eaeodkg                nloadd  5ed3d67b8723c11444c43283
# 16          adyuns               naczhai  5ed3d67b8723c11444c43283
# 17       aiblnafoa              ollutoep  5ed3d67b8723c11444c43283
# 18          dokeay         egesr jmumoan  5ed3d67b8723c11444c43283
# 19    e okowuhoonw             izahbteel  5ed3d67b8723c11444c43283
# 20        imawinuk                iadmil  5ed3d67b8723c11444c43283
# 21           kroow                 odqis  5ed3d67b8723c11444c43283
# 22       oogbnslou               lezeeki  5ed3d67b8723c11444c43283
# 23           oujkn  aoiu ulaleafdosmyoln  5ed3d67b8723c11444c43283
# 24          aimuwy                 measj  5ed3d67b8723c11444c43283
# 25      anygoeeldu              dllaamio  5ed3d67b8723c11444c43283
# 26           uiwdo  audelb mllooaialunof  5ed3d67b8723c11444c43283
# 27        yaeikdno       o saederifaahbl  5ed3d67b8723c11444c43283
# 28             joo                 lexce  5ed3d67b8723c11444c43283
# 29         oyeewal             aimolewfu  5ed3d67b8723c11444c43283
# 118  2020-06-13T06:00:46.904000Z      29627   Debit     mobile     GBank
# 119  2020-06-13T16:10:51.479000Z      27791   Debit        web     KBank
# 120  2020-06-13T05:28:47.543000Z       6192   Debit        web     QBank
# 121  2020-06-12T20:22:38.986000Z      38445   Debit     mobile     ABank
# 122  2020-06-13T06:00:46.904000Z      29627   Debit     mobile     GBank
# 123  2020-06-13T16:10:51.479000Z      27791   Debit        web     KBank
# 124  2020-06-13T05:28:47.543000Z       6192   Debit        web     QBank
# 125  2020-06-12T20:22:38.986000Z      38445   Debit     mobile     ABank
# 126  2020-06-13T06:00:46.904000Z      29627   Debit     mobile     GBank
#
#      year_of_birth  age
# 0             1992   28
# 1             2020   11
# 2             1992   28
# 3             1981   39
# 4             2020   11
# 5             1980   40
# 6             1998   22
# 7             1976   44
# 8             1976   44
# 9             2020   11
# 10            2020   11
# 11            2020   11
# 12            2020   11
# 13            1984   36
# 14            2020   11
# 15            2020   11
# 16            2020   11
# 17            2020   11
# 18            2020   11
# 19            2020   11
# 20            2020   11
# 21            2020   11
# 22            1981   39
# 23            1989   31
# 24            1981   39
# 25            2020   11
# 26            2020   11
# 27            2020   11
# 28            1999   21
# 29            2020   11
# ..             ...  ...
# 97            2020   11
# 98            1993   27
# 99            2020   11
# 100           1984   36
# 101           2020   11
# 102           2020   11
# 103           2020   11
# 104           2020   11
# 105           2020   11
# 106           2020   11
# 107           1992   28
# 108           1974   46
# 109           1999   21
# 110           2020   11
# 111           2020   11
# 112           2000   20
# 113           1980   40
# 114           2020   11
# 115           2020   11
# 116           1987   33
# 117           2020   11
# 118           2020   11
# 119           2020   11
# 120           2020   11
# 121           2020   11
# 122           2020   11
# 123           2020   11
# 124           2020   11
# 125           2020   11
# 126           2020   11
#
# [127 rows x 10 columns]

# %%
df8.to_excel('new_cleaned_data.xlsx', index=False)

# %%
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
matplotlib.rcParams["figure.figsize"] = (13,5)

# %%
#plt.bar(df8['age'],)
y = np.arange(len(df8))
plt.bar(df8['age'], y)

plt.xlabel('Ages')
plt.ylabel('Amount of People')
plt.title('Ages with there numbers')
# Out:
# Text(0.5, 1.0, 'Ages with there numbers')

# %% [markdown]
# It is observed that the customers with ambiguous ages(11yrs) dominate followed by customers in their early thirties, then forties, then twenties.

# %%
df8.groupby('bank_name')['tx_amount'].sum()
# Out:
# bank_name
# ABank    1230240
# GBank     948064
# KBank     861521
# QBank     198144
# Name: tx_amount, dtype: int64

# %% [markdown]
# Obviously, the bank with the largest share is ABank

# %%
plt.bar(df8['bank_name'], df8['tx_amount'], width=0.3)
# Out:
# <BarContainer object of 127 artists>

# %%
#Distribution of channels used on transaction

df8.groupby('tx_channel')['tx_channel'].count()
# Out:
# tx_channel
# mobile    64
# web       63
# Name: tx_channel, dtype: int64

# %%
plt.bar(df8['tx_channel'], y, width=0.1)
# Out:
# <BarContainer object of 127 artists>
